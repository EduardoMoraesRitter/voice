# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoMoraesRitter/voice/blob/master/cat_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/mmoreaux/audio-cats-and-dogs/kernels

# %%
pip install tuner
# Out:
# Collecting tuner
#   Downloading https://files.pythonhosted.org/packages/56/69/d131a7517cf5398220bcd50aa20fa0c9f18331b0b6c12cd4943446b446f8/tuner-1.0.0b2-py3-none-any.whl
# Collecting pyaudio
#   Downloading https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Collecting pymlconf
#   Downloading https://files.pythonhosted.org/packages/5c/30/7a036296086ce70572da9c854b4de07c555257826a36827f116f802088e9/pymlconf-2.2.0-py3-none-any.whl
# Collecting kivy
#   Downloading https://files.pythonhosted.org/packages/23/4d/e32e93eecdc8740a0f5c389c3b65acb8621a330615381478a874510c7b29/Kivy-1.11.1-cp36-cp36m-manylinux2010_x86_64.whl (28.3MB)
#      |████████████████████████████████| 28.3MB 124kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tuner) (1.17.5)
# Collecting pygame
#   Downloading https://files.pythonhosted.org/packages/8e/24/ede6428359f913ed9cd1643dd5533aefeb5a2699cc95bea089de50ead586/pygame-1.9.6-cp36-cp36m-manylinux1_x86_64.whl (11.4MB)
#      |████████████████████████████████| 11.4MB 22.1MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from tuner) (1.4.1)
# Requirement already satisfied: pyyaml>=3.10 in /usr/local/lib/python3.6/dist-packages (from pymlconf->tuner) (3.13)
# Requirement already satisfied: docutils in /usr/local/lib/python3.6/dist-packages (from kivy->tuner) (0.15.2)
# Collecting Kivy-Garden>=0.1.4
#   Downloading https://files.pythonhosted.org/packages/7d/68/decaee596ff8168a39432eb3949fc7c0be952ebb9467806823bffc165d48/kivy-garden-0.1.4.tar.gz
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from kivy->tuner) (2.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from Kivy-Garden>=0.1.4->kivy->tuner) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy->tuner) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy->tuner) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy->tuner) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy->tuner) (2019.11.28)
# Building wheels for collected packages: pyaudio, Kivy-Garden
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
#   Building wheel for Kivy-Garden (setup.py) ... done
#   Created wheel for Kivy-Garden: filename=Kivy_Garden-0.1.4-cp36-none-any.whl size=4532 sha256=89a7591c660eba0dd7341e82bc397ad06053113d70c31559687c8fd8ad859002
#   Stored in directory: /root/.cache/pip/wheels/e5/09/36/4bec048252175b6aa7ba75441cbeed8f31a0bea37abedcfed0
# Successfully built Kivy-Garden
# Failed to build pyaudio
# Installing collected packages: pyaudio, pymlconf, Kivy-Garden, kivy, pygame, tuner
#     Running setup.py install for pyaudio ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-abnwf897/pyaudio/setup.py'"'"'; __file__='"'"'/tmp/pip-install-abnwf897/pyaudio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-yb3rp7xe/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
# audio analysis libraries
library(tuneR)
library(seewave)

# read in a single cat & single dog file 
cat <- readWave("./cat_100.wav")
dog <- readWave("./dog_barking_100.wav")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7a81d0c1565> in <module>()
# ----> 1 library(tuneR)
#       2 library(seewave)
#       3
#       4 # read in a single cat & single dog file
#       5 cat <- readWave("./cat_100.wav")
#
# NameError: name 'library' is not defined

# %%
# draw a spectogram of the cat 
spectro(cat)

# %%
# draw a spectogram of the cat 
spectro(dog)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy.io.wavfile as sci_wav # Open wav files
import os  # Manipulate files
import matplotlib.pyplot as plt # Plotting
import librosa
# %matplotlib inline

fs = 16000 # 16kHz sampling rate

cat_path = './cat_110.wav'
dog_path = './dog_barking_112.wav'
inspect_cat = np.array(librosa.load(cat_path)[0])
inspect_dog = np.array(librosa.load(dog_path)[0])

# %%
fig, (ax_cat_5, ax_dog_5) = plt.subplots(2, 1) # subplot for section 5
ax_cat_5.plot(inspect_cat)
ax_cat_5.set_title(cat_path)
ax_cat_5.set_xlabel("Samples")
ax_dog_5.plot(inspect_dog)
ax_dog_5.set_title(dog_path)
ax_dog_5.set_xlabel("Samples")
plt.subplots_adjust(hspace = 0.75)
plt.show()

# %%
import IPython.display as ipd
ipd.Audio(inspect_dog,rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(inspect_cat,rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig_6, (ax_cat_6, ax_dog_6) = plt.subplots(1, 2) # subplot for section 6
Pxx_cat, freqs_cat, bins_cat, im_cat = ax_cat_6.specgram(inspect_cat, Fs = fs)
ax_cat_6.set_title(cat_path)
ax_cat_6.set_xlabel("Time [sec]")
ax_cat_6.set_ylabel("Frequency [Hz]")
Pxx_dog, freqs_dog, bins_dog, im_dog = ax_dog_6.specgram(inspect_dog, Fs = fs)
ax_dog_6.set_title(dog_path)
ax_dog_6.set_xlabel("Time [sec]")
ax_dog_6.set_ylabel("Frequency [Hz]")
plt.subplots_adjust(right = 2)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:7747: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
mfcc_cat = librosa.feature.mfcc(y = inspect_cat, sr = fs)
mfcc_dog = librosa.feature.mfcc(y = inspect_dog, sr = fs)
fig_7, (ax_cat_7, ax_dog_7) = plt.subplots(1, 2)
ax_cat_7.imshow(mfcc_cat, cmap = 'hot', interpolation = 'nearest')
ax_cat_7.set_title(cat_path)
ax_dog_7.imshow(mfcc_dog, cmap = 'hot', interpolation = 'nearest')
ax_dog_7.set_title(dog_path)
plt.subplots_adjust(right = 2)
plt.show()
